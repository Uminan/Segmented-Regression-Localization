# %%
from __future__ import print_function, division
import os
import torch
import pandas as pd
from skimage import io, transform
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils, datasets, models

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
#from lib import RadioUNet_modules3, RadioUNet_loaders2
from lib import loaders, modules

# %% [markdown]
# ## Dataset Loader, RadioUNetc threshold=0.2

# %%
import torch
from torch.utils.data import DataLoader, RandomSampler
Radio_train = loaders.RadioUNet_s(phase="train",fix_samples=300, carsSimul="no", carsInput="no")
Radio_val = loaders.RadioUNet_s(phase="val",fix_samples=300, carsSimul="no", carsInput="no")
Radio_test = loaders.RadioUNet_s(phase="test",fix_samples=300, carsSimul="no", carsInput="no")

# image_datasets = {
#     'train': Radio_train, 'val': Radio_val
# }

# batch_size = 30

# dataloaders = {
#     'train': DataLoader(Radio_train, batch_size=batch_size, shuffle=True, num_workers=1),
#     'val': DataLoader(Radio_val, batch_size=batch_size, shuffle=True, num_workers=1)
# }

image_datasets = {
    'train': Radio_train, 'val': Radio_val
}

batch_size = 120

# 创建 generator 并确保它在 CUDA 设备上
generator = torch.Generator(device='cuda')

# 创建 RandomSampler 并传递 generator
train_sampler = RandomSampler(Radio_train, generator=generator)
val_sampler = RandomSampler(Radio_val, generator=generator)

# 创建 DataLoader 并传递 RandomSampler
dataloaders = {
    'train': DataLoader(Radio_train, batch_size=batch_size, sampler=train_sampler, num_workers=1),
    'val': DataLoader(Radio_val, batch_size=batch_size, sampler=val_sampler, num_workers=1)
}

# %% [markdown]
# ## Test Sample Image

# %%
i=1000
image_build_ant, image_gain = Radio_train[i]
plt.imshow(image_gain[0])

# %%
i=1000
image_build_ant, image_gain = Radio_train[i]
plt.imshow(image_build_ant[1])

# %% [markdown]
# ## Load Model and Summary

# %%
# from torchsummary import summary

torch.set_default_dtype(torch.float32)
torch.set_default_tensor_type('torch.cuda.FloatTensor')
torch.backends.cudnn.enabled
model =modules.RadioWNet(inputs=2, phase="firstU")
model.cuda()
# summary(model, input_size=(4, 256,256))
# Out:
# RadioWNet(
#   (layer00): Sequential(
#     (0): Conv2d(2, 6, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer0): Sequential(
#     (0): Conv2d(6, 40, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer1): Sequential(
#     (0): Conv2d(40, 50, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer10): Sequential(
#     (0): Conv2d(50, 60, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(60, 100, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer20): Sequential(
#     (0): Conv2d(100, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer3): Sequential(
#     (0): Conv2d(100, 150, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer4): Sequential(
#     (0): Conv2d(150, 300, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer5): Sequential(
#     (0): Conv2d(300, 500, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_up5): Sequential(
#     (0): ConvTranspose2d(500, 300, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (conv_up4): Sequential(
#     (0): ConvTranspose2d(600, 150, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (conv_up3): Sequential(
#     (0): ConvTranspose2d(300, 100, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (conv_up20): Sequential(
#     (0): Conv2d(200, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_up2): Sequential(
#     (0): ConvTranspose2d(200, 60, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#     (1): ReLU(inplace=True)
#   )
#   (conv_up10): Sequential(
#     (0): Conv2d(120, 50, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_up1): Sequential(
#     (0): ConvTranspose2d(100, 40, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#     (1): ReLU(inplace=True)
#   )
#   (conv_up0): Sequential(
#     (0): ConvTranspose2d(80, 20, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#     (1): ReLU(inplace=True)
#   )
#   (conv_up00): Sequential(
#     (0): Conv2d(28, 20, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_up000): Sequential(
#     (0): Conv2d(22, 1, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer00): Sequential(
#     (0): Conv2d(3, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer0): Sequential(
#     (0): Conv2d(20, 30, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer1): Sequential(
#     (0): Conv2d(30, 40, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer10): Sequential(
#     (0): Conv2d(40, 50, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer2): Sequential(
#     (0): Conv2d(50, 60, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer20): Sequential(
#     (0): Conv2d(60, 70, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer3): Sequential(
#     (0): Conv2d(70, 90, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer4): Sequential(
#     (0): Conv2d(90, 110, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer5): Sequential(
#     (0): Conv2d(110, 150, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wconv_up5): Sequential(
#     (0): ConvTranspose2d(150, 110, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (Wconv_up4): Sequential(
#     (0): ConvTranspose2d(220, 90, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (Wconv_up3): Sequential(
#     (0): ConvTranspose2d(180, 70, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (Wconv_up20): Sequential(
#     (0): Conv2d(140, 60, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wconv_up2): Sequential(
#     (0): ConvTranspose2d(120, 50, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#     (1): ReLU(inplace=True)
#   )
#   (Wconv_up10): Sequential(
#     (0): Conv2d(100, 40, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wconv_up1): Sequential(
#     (0): ConvTranspose2d(80, 30, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#     (1): ReLU(inplace=True)
#   )
#   (Wconv_up0): Sequential(
#     (0): ConvTranspose2d(60, 20, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#     (1): ReLU(inplace=True)
#   )
#   (Wconv_up00): Sequential(
#     (0): Conv2d(43, 20, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wconv_up000): Sequential(
#     (0): Conv2d(23, 1, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
# )

# %% [markdown]
# ## Training Loop

# %%
#Adapted from https://github.com/usuyama/pytorch-unet

import torch
import torch.optim as optim
from torch.optim import lr_scheduler
import time
import copy
from collections import defaultdict
import torch.nn.functional as F
import torch.nn as nn

def calc_loss_dense(pred, target, metrics):
    criterion = nn.MSELoss()
    loss = criterion(pred, target)
    metrics['loss'] += loss.data.cpu().numpy() * target.size(0)

    return loss

def calc_loss_sparse(pred, target, samples, metrics, num_samples):
    criterion = nn.MSELoss()
    loss = criterion(samples*pred, samples*target)*(256**2)/num_samples
    metrics['loss'] += loss.data.cpu().numpy() * target.size(0)

    return loss

def print_metrics(metrics, epoch_samples, phase):
    outputs1 = []
    outputs2 = []
    for k in metrics.keys():
        outputs1.append("{}: {:4f}".format(k, metrics[k] / (epoch_samples*256**2)))

    print("{}: {}".format(phase, ", ".join(outputs1)))

def train_model(model, optimizer, scheduler, num_epochs=50, WNetPhase="firstU", targetType="dense", num_samples=300):
    # WNetPhase: traine first U and freez second ("firstU"), or vice verse ("secondU").
    # targetType: train against dense images ("dense") or sparse measurements ("sparse")
    best_model_wts = copy.deepcopy(model.state_dict())
    best_loss = 1e10

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        since = time.time()

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                scheduler.step()
                for param_group in optimizer.param_groups:
                    print("learning rate", param_group['lr'])

                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            metrics = defaultdict(float)
            epoch_samples = 0

            if targetType=="dense":
                for inputs, targets in dataloaders[phase]:
                    inputs = inputs.to(device)
                    targets = targets.to(device)

                    # zero the parameter gradients
                    optimizer.zero_grad()

                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == 'train'):
                        [outputs1,outputs2] = model(inputs)
                        if WNetPhase=="firstU":
                            loss = calc_loss_dense(outputs1, targets, metrics)
                        else:
                            loss = calc_loss_dense(outputs2, targets, metrics)

                        # backward + optimize only if in training phase
                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    # statistics
                    epoch_samples += inputs.size(0)
            elif targetType=="sparse":
                for inputs, targets, samples in dataloaders[phase]:
                    inputs = inputs.to(device)
                    targets = targets.to(device)
                    samples = samples.to(device)

                    # zero the parameter gradients
                    optimizer.zero_grad()

                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == 'train'):
                        [outputs1,outputs2] = model(inputs)
                        if WNetPhase=="firstU":
                            loss = calc_loss_sparse(outputs1, targets, samples, metrics, num_samples)
                        else:
                            loss = calc_loss_sparse(outputs2, targets, samples, metrics, num_samples)

                        # backward + optimize only if in training phase
                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    # statistics
                    epoch_samples += inputs.size(0)

            print_metrics(metrics, epoch_samples, phase)
            epoch_loss = metrics['loss'] / epoch_samples

            # deep copy the model
            if phase == 'val' and epoch_loss < best_loss:
                print("saving best model")
                best_loss = epoch_loss
                best_model_wts = copy.deepcopy(model.state_dict())

        time_elapsed = time.time() - since
        print('{:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))

    print('Best val loss: {:4f}'.format(best_loss))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %% [markdown]
# ## Training First UNet

# %%
import torch
import torch.optim as optim
from torch.optim import lr_scheduler
import time
import copy

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)


optimizer_ft = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-4)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=30, gamma=0.1)

model = train_model(model, optimizer_ft, exp_lr_scheduler)
# Out:
# cuda:0
# Epoch 0/49
# ----------
# learning rate 0.0001
# train: loss: 0.014777
# val: loss: 0.008924
# saving best model
# 2m 54s
# Epoch 1/49
# ----------
# learning rate 0.0001
# train: loss: 0.006015
# val: loss: 0.003557
# saving best model
# 2m 54s
# Epoch 2/49
# ----------
# learning rate 0.0001
# train: loss: 0.002913
# val: loss: 0.002366
# saving best model
# 2m 55s
# Epoch 3/49
# ----------
# learning rate 0.0001
# train: loss: 0.002281
# val: loss: 0.002086
# saving best model
# 2m 54s
# Epoch 4/49
# ----------
# learning rate 0.0001
# train: loss: 0.002025
# val: loss: 0.002178
# 2m 54s
# Epoch 5/49
# ----------
# learning rate 0.0001
# train: loss: 0.001849
# val: loss: 0.001713
# saving best model
# 2m 54s
# Epoch 6/49
# ----------
# learning rate 0.0001
# train: loss: 0.001709
# val: loss: 0.001551
# saving best model
# 2m 54s
# Epoch 7/49
# ----------
# learning rate 0.0001
# train: loss: 0.001556
# val: loss: 0.001416
# saving best model
# 2m 54s
# Epoch 8/49
# ----------
# learning rate 0.0001
# train: loss: 0.001445
# val: loss: 0.001497
# 2m 54s
# Epoch 9/49
# ----------
# learning rate 0.0001
# train: loss: 0.001336
# val: loss: 0.001231
# saving best model
# 2m 54s
# Epoch 10/49
# ----------
# learning rate 0.0001
# train: loss: 0.001217
# val: loss: 0.001117
# saving best model
# 2m 54s
# Epoch 11/49
# ----------
# learning rate 0.0001
# train: loss: 0.001122
# val: loss: 0.001045
# saving best model
# 2m 54s
# Epoch 12/49
# ----------
# learning rate 0.0001
# train: loss: 0.001059
# val: loss: 0.000974
# saving best model
# 2m 54s
# Epoch 13/49
# ----------
# learning rate 0.0001
# train: loss: 0.001014
# val: loss: 0.000953
# saving best model
# 2m 54s
# Epoch 14/49
# ----------
# learning rate 0.0001
# train: loss: 0.000960
# val: loss: 0.000926
# saving best model
# 2m 55s
# Epoch 15/49
# ----------
# learning rate 0.0001
# train: loss: 0.000933
# val: loss: 0.000866
# saving best model
# 2m 54s
# Epoch 16/49
# ----------
# learning rate 0.0001
# train: loss: 0.000893
# val: loss: 0.000853
# saving best model
# 2m 54s
# Epoch 17/49
# ----------
# learning rate 0.0001
# train: loss: 0.000868
# val: loss: 0.000822
# saving best model
# 2m 54s
# Epoch 18/49
# ----------
# learning rate 0.0001
# train: loss: 0.000845
# val: loss: 0.000811
# saving best model
# 2m 55s
# Epoch 19/49
# ----------
# learning rate 0.0001
# train: loss: 0.000823
# val: loss: 0.000794
# saving best model
# 2m 54s
# Epoch 20/49
# ----------
# learning rate 0.0001
# train: loss: 0.000803
# val: loss: 0.000748
# saving best model
# 2m 54s
# Epoch 21/49
# ----------
# learning rate 0.0001
# train: loss: 0.000784
# val: loss: 0.000733
# saving best model
# 2m 54s
# Epoch 22/49
# ----------
# learning rate 0.0001
# train: loss: 0.000762
# val: loss: 0.000724
# saving best model
# 2m 54s
# Epoch 23/49
# ----------
# learning rate 0.0001
# train: loss: 0.000749
# val: loss: 0.000779
# 2m 54s
# Epoch 24/49
# ----------
# learning rate 0.0001
# train: loss: 0.000735
# val: loss: 0.000696
# saving best model
# 2m 54s
# Epoch 25/49
# ----------
# learning rate 0.0001
# train: loss: 0.000717
# val: loss: 0.000680
# saving best model
# 2m 54s
# Epoch 26/49
# ----------
# learning rate 0.0001
# train: loss: 0.000701
# val: loss: 0.000660
# saving best model
# 2m 54s
# Epoch 27/49
# ----------
# learning rate 0.0001
# train: loss: 0.000683
# val: loss: 0.000639
# saving best model
# 2m 54s
# Epoch 28/49
# ----------
# learning rate 0.0001
# train: loss: 0.000673
# val: loss: 0.000665
# 2m 54s
# Epoch 29/49
# ----------
# learning rate 1e-05
# train: loss: 0.000647
# val: loss: 0.000620
# saving best model
# 2m 54s
# Epoch 30/49
# ----------
# learning rate 1e-05
# train: loss: 0.000644
# val: loss: 0.000617
# saving best model
# 2m 54s
# Epoch 31/49
# ----------
# learning rate 1e-05
# train: loss: 0.000643
# val: loss: 0.000617
# saving best model
# 2m 54s
# Epoch 32/49
# ----------
# learning rate 1e-05
# train: loss: 0.000641
# val: loss: 0.000614
# saving best model
# 2m 54s
# Epoch 33/49
# ----------
# learning rate 1e-05
# train: loss: 0.000638
# val: loss: 0.000612
# saving best model
# 2m 54s
# Epoch 34/49
# ----------
# learning rate 1e-05
# train: loss: 0.000636
# val: loss: 0.000611
# saving best model
# 2m 54s
# Epoch 35/49
# ----------
# learning rate 1e-05
# train: loss: 0.000634
# val: loss: 0.000606
# saving best model
# 2m 54s
# Epoch 36/49
# ----------
# learning rate 1e-05
# train: loss: 0.000631
# val: loss: 0.000603
# saving best model
# 2m 54s
# Epoch 37/49
# ----------
# learning rate 1e-05
# train: loss: 0.000628
# val: loss: 0.000601
# saving best model
# 2m 54s
# Epoch 38/49
# ----------
# learning rate 1e-05
# train: loss: 0.000625
# val: loss: 0.000600
# saving best model
# 2m 54s
# Epoch 39/49
# ----------
# learning rate 1e-05
# train: loss: 0.000621
# val: loss: 0.000596
# saving best model
# 2m 54s
# Epoch 40/49
# ----------
# learning rate 1e-05
# train: loss: 0.000619
# val: loss: 0.000594
# saving best model
# 2m 54s
# Epoch 41/49
# ----------
# learning rate 1e-05
# train: loss: 0.000616
# val: loss: 0.000589
# saving best model
# 2m 54s
# Epoch 42/49
# ----------
# learning rate 1e-05
# train: loss: 0.000613
# val: loss: 0.000588
# saving best model
# 2m 54s
# Epoch 43/49
# ----------
# learning rate 1e-05
# train: loss: 0.000610
# val: loss: 0.000586
# saving best model
# 2m 54s
# Epoch 44/49
# ----------
# learning rate 1e-05
# train: loss: 0.000607
# val: loss: 0.000582
# saving best model
# 2m 54s
# Epoch 45/49
# ----------
# learning rate 1e-05
# train: loss: 0.000605
# val: loss: 0.000581
# saving best model
# 2m 54s
# Epoch 46/49
# ----------
# learning rate 1e-05
# train: loss: 0.000601
# val: loss: 0.000578
# saving best model
# 2m 54s
# Epoch 47/49
# ----------
# learning rate 1e-05
# train: loss: 0.000599
# val: loss: 0.000576
# saving best model
# 2m 54s
# Epoch 48/49
# ----------
# learning rate 1e-05
# train: loss: 0.000596
# val: loss: 0.000573
# saving best model
# 2m 54s
# Epoch 49/49
# ----------
# learning rate 1e-05
# train: loss: 0.000593
# val: loss: 0.000570
# saving best model
# 2m 54s
# Best val loss: 37.379154

# %% [markdown]
# ## Create Directory For Saving the Model and Examples

# %%
import os
try: 
    os.mkdir('RadioWNet_s_DPMcars_carInput_Thr2') 
except OSError as error: 
    print(error)
# Out:
# [Errno 17] File exists: 'RadioWNet_s_DPMcars_carInput_Thr2'

# %% [markdown]
# ## Save First U Model For Inference

# %%
torch.save(model.state_dict(), 'RadioWNet_s_DPMcars_carInput_Thr2/300samples_FirstU.pt')

# %% [markdown]
# ## Load Second U Model For Inference

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = modules.RadioWNet(inputs=2, phase="firstU")
model.load_state_dict(torch.load('RadioWNet_s_DPMcars_carInput_Thr2/300samples_FirstU.pt'))
model.to(device)
# Out:
# RadioWNet(
#   (layer00): Sequential(
#     (0): Conv2d(2, 6, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer0): Sequential(
#     (0): Conv2d(6, 40, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer1): Sequential(
#     (0): Conv2d(40, 50, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer10): Sequential(
#     (0): Conv2d(50, 60, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(60, 100, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer20): Sequential(
#     (0): Conv2d(100, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer3): Sequential(
#     (0): Conv2d(100, 150, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer4): Sequential(
#     (0): Conv2d(150, 300, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer5): Sequential(
#     (0): Conv2d(300, 500, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_up5): Sequential(
#     (0): ConvTranspose2d(500, 300, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (conv_up4): Sequential(
#     (0): ConvTranspose2d(600, 150, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (conv_up3): Sequential(
#     (0): ConvTranspose2d(300, 100, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (conv_up20): Sequential(
#     (0): Conv2d(200, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_up2): Sequential(
#     (0): ConvTranspose2d(200, 60, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#     (1): ReLU(inplace=True)
#   )
#   (conv_up10): Sequential(
#     (0): Conv2d(120, 50, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_up1): Sequential(
#     (0): ConvTranspose2d(100, 40, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#     (1): ReLU(inplace=True)
#   )
#   (conv_up0): Sequential(
#     (0): ConvTranspose2d(80, 20, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#     (1): ReLU(inplace=True)
#   )
#   (conv_up00): Sequential(
#     (0): Conv2d(28, 20, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_up000): Sequential(
#     (0): Conv2d(22, 1, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer00): Sequential(
#     (0): Conv2d(3, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer0): Sequential(
#     (0): Conv2d(20, 30, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer1): Sequential(
#     (0): Conv2d(30, 40, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer10): Sequential(
#     (0): Conv2d(40, 50, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer2): Sequential(
#     (0): Conv2d(50, 60, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer20): Sequential(
#     (0): Conv2d(60, 70, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer3): Sequential(
#     (0): Conv2d(70, 90, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer4): Sequential(
#     (0): Conv2d(90, 110, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer5): Sequential(
#     (0): Conv2d(110, 150, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wconv_up5): Sequential(
#     (0): ConvTranspose2d(150, 110, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (Wconv_up4): Sequential(
#     (0): ConvTranspose2d(220, 90, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (Wconv_up3): Sequential(
#     (0): ConvTranspose2d(180, 70, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (Wconv_up20): Sequential(
#     (0): Conv2d(140, 60, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wconv_up2): Sequential(
#     (0): ConvTranspose2d(120, 50, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#     (1): ReLU(inplace=True)
#   )
#   (Wconv_up10): Sequential(
#     (0): Conv2d(100, 40, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wconv_up1): Sequential(
#     (0): ConvTranspose2d(80, 30, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#     (1): ReLU(inplace=True)
#   )
#   (Wconv_up0): Sequential(
#     (0): ConvTranspose2d(60, 20, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#     (1): ReLU(inplace=True)
#   )
#   (Wconv_up00): Sequential(
#     (0): Conv2d(43, 20, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wconv_up000): Sequential(
#     (0): Conv2d(23, 1, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
# )

# %% [markdown]
# ## Second U Module

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model =modules.RadioWNet(inputs=2, phase="secondU")
model.load_state_dict(torch.load('RadioWNet_s_DPMcars_carInput_Thr2/300samples_FirstU.pt'))
model.to(device)
# Out:
# RadioWNet(
#   (layer00): Sequential(
#     (0): Conv2d(2, 6, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer0): Sequential(
#     (0): Conv2d(6, 40, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer1): Sequential(
#     (0): Conv2d(40, 50, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer10): Sequential(
#     (0): Conv2d(50, 60, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(60, 100, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer20): Sequential(
#     (0): Conv2d(100, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer3): Sequential(
#     (0): Conv2d(100, 150, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer4): Sequential(
#     (0): Conv2d(150, 300, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer5): Sequential(
#     (0): Conv2d(300, 500, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_up5): Sequential(
#     (0): ConvTranspose2d(500, 300, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (conv_up4): Sequential(
#     (0): ConvTranspose2d(600, 150, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (conv_up3): Sequential(
#     (0): ConvTranspose2d(300, 100, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (conv_up20): Sequential(
#     (0): Conv2d(200, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_up2): Sequential(
#     (0): ConvTranspose2d(200, 60, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#     (1): ReLU(inplace=True)
#   )
#   (conv_up10): Sequential(
#     (0): Conv2d(120, 50, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_up1): Sequential(
#     (0): ConvTranspose2d(100, 40, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#     (1): ReLU(inplace=True)
#   )
#   (conv_up0): Sequential(
#     (0): ConvTranspose2d(80, 20, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#     (1): ReLU(inplace=True)
#   )
#   (conv_up00): Sequential(
#     (0): Conv2d(28, 20, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_up000): Sequential(
#     (0): Conv2d(22, 1, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer00): Sequential(
#     (0): Conv2d(3, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer0): Sequential(
#     (0): Conv2d(20, 30, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer1): Sequential(
#     (0): Conv2d(30, 40, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer10): Sequential(
#     (0): Conv2d(40, 50, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer2): Sequential(
#     (0): Conv2d(50, 60, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer20): Sequential(
#     (0): Conv2d(60, 70, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer3): Sequential(
#     (0): Conv2d(70, 90, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer4): Sequential(
#     (0): Conv2d(90, 110, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer5): Sequential(
#     (0): Conv2d(110, 150, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wconv_up5): Sequential(
#     (0): ConvTranspose2d(150, 110, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (Wconv_up4): Sequential(
#     (0): ConvTranspose2d(220, 90, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (Wconv_up3): Sequential(
#     (0): ConvTranspose2d(180, 70, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (Wconv_up20): Sequential(
#     (0): Conv2d(140, 60, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wconv_up2): Sequential(
#     (0): ConvTranspose2d(120, 50, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#     (1): ReLU(inplace=True)
#   )
#   (Wconv_up10): Sequential(
#     (0): Conv2d(100, 40, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wconv_up1): Sequential(
#     (0): ConvTranspose2d(80, 30, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#     (1): ReLU(inplace=True)
#   )
#   (Wconv_up0): Sequential(
#     (0): ConvTranspose2d(60, 20, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#     (1): ReLU(inplace=True)
#   )
#   (Wconv_up00): Sequential(
#     (0): Conv2d(43, 20, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wconv_up000): Sequential(
#     (0): Conv2d(23, 1, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
# )

# %% [markdown]
# ## Training Scond UNet

# %%
import torch
import torch.optim as optim
from torch.optim import lr_scheduler
import time
import copy

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)


optimizer_ft = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-4)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=30, gamma=0.1)

model = train_model(model, optimizer_ft, exp_lr_scheduler, WNetPhase="secondU")
# Out:
# cuda:0
# Epoch 0/49
# ----------
# learning rate 0.0001
# train: loss: 0.003256
# val: loss: 0.000755
# saving best model
# 2m 46s
# Epoch 1/49
# ----------
# learning rate 0.0001
# train: loss: 0.000688
# val: loss: 0.000620
# saving best model
# 2m 47s
# Epoch 2/49
# ----------
# learning rate 0.0001
# train: loss: 0.000620
# val: loss: 0.000586
# saving best model
# 2m 47s
# Epoch 3/49
# ----------
# learning rate 0.0001
# train: loss: 0.000595
# val: loss: 0.000571
# saving best model
# 2m 46s
# Epoch 4/49
# ----------
# learning rate 0.0001
# train: loss: 0.000579
# val: loss: 0.000554
# saving best model
# 2m 47s
# Epoch 5/49
# ----------
# learning rate 0.0001
# train: loss: 0.000567
# val: loss: 0.000547
# saving best model
# 2m 47s
# Epoch 6/49
# ----------
# learning rate 0.0001
# train: loss: 0.000558
# val: loss: 0.000535
# saving best model
# 2m 47s
# Epoch 7/49
# ----------
# learning rate 0.0001
# train: loss: 0.000548
# val: loss: 0.000527
# saving best model
# 2m 47s
# Epoch 8/49
# ----------
# learning rate 0.0001
# train: loss: 0.000539
# val: loss: 0.000520
# saving best model
# 2m 47s
# Epoch 9/49
# ----------
# learning rate 0.0001
# train: loss: 0.000530
# val: loss: 0.000511
# saving best model
# 2m 47s
# Epoch 10/49
# ----------
# learning rate 0.0001
# train: loss: 0.000521
# val: loss: 0.000501
# saving best model
# 2m 47s
# Epoch 11/49
# ----------
# learning rate 0.0001
# train: loss: 0.000511
# val: loss: 0.000498
# saving best model
# 2m 47s
# Epoch 12/49
# ----------
# learning rate 0.0001
# train: loss: 0.000501
# val: loss: 0.000490
# saving best model
# 2m 47s
# Epoch 13/49
# ----------
# learning rate 0.0001
# train: loss: 0.000492
# val: loss: 0.000476
# saving best model
# 2m 47s
# Epoch 14/49
# ----------
# learning rate 0.0001
# train: loss: 0.000481
# val: loss: 0.000469
# saving best model
# 2m 47s
# Epoch 15/49
# ----------
# learning rate 0.0001
# train: loss: 0.000472
# val: loss: 0.000459
# saving best model
# 2m 47s
# Epoch 16/49
# ----------
# learning rate 0.0001
# train: loss: 0.000464
# val: loss: 0.000455
# saving best model
# 2m 46s
# Epoch 17/49
# ----------
# learning rate 0.0001
# train: loss: 0.000454
# val: loss: 0.000445
# saving best model
# 2m 46s
# Epoch 18/49
# ----------
# learning rate 0.0001
# train: loss: 0.000447
# val: loss: 0.000437
# saving best model
# 2m 47s
# Epoch 19/49
# ----------
# learning rate 0.0001
# train: loss: 0.000439
# val: loss: 0.000430
# saving best model
# 2m 47s
# Epoch 20/49
# ----------
# learning rate 0.0001
# train: loss: 0.000431
# val: loss: 0.000424
# saving best model
# 2m 46s
# Epoch 21/49
# ----------
# learning rate 0.0001
# train: loss: 0.000424
# val: loss: 0.000421
# saving best model
# 2m 47s
# Epoch 22/49
# ----------
# learning rate 0.0001
# train: loss: 0.000418
# val: loss: 0.000412
# saving best model
# 2m 47s
# Epoch 23/49
# ----------
# learning rate 0.0001
# train: loss: 0.000410
# val: loss: 0.000406
# saving best model
# 2m 46s
# Epoch 24/49
# ----------
# learning rate 0.0001
# train: loss: 0.000404
# val: loss: 0.000402
# saving best model
# 2m 47s
# Epoch 25/49
# ----------
# learning rate 0.0001
# train: loss: 0.000397
# val: loss: 0.000396
# saving best model
# 2m 47s
# Epoch 26/49
# ----------
# learning rate 0.0001
# train: loss: 0.000392
# val: loss: 0.000393
# saving best model
# 2m 47s
# Epoch 27/49
# ----------
# learning rate 0.0001
# train: loss: 0.000385
# val: loss: 0.000387
# saving best model
# 2m 47s
# Epoch 28/49
# ----------
# learning rate 0.0001
# train: loss: 0.000381
# val: loss: 0.000387
# 2m 47s
# Epoch 29/49
# ----------
# learning rate 1e-05
# train: loss: 0.000374
# val: loss: 0.000381
# saving best model
# 2m 47s
# Epoch 30/49
# ----------
# learning rate 1e-05
# train: loss: 0.000373
# val: loss: 0.000380
# saving best model
# 2m 46s
# Epoch 31/49
# ----------
# learning rate 1e-05
# train: loss: 0.000372
# val: loss: 0.000379
# saving best model
# 2m 47s
# Epoch 32/49
# ----------
# learning rate 1e-05
# train: loss: 0.000371
# val: loss: 0.000379
# 2m 46s
# Epoch 33/49
# ----------
# learning rate 1e-05
# train: loss: 0.000370
# val: loss: 0.000379
# saving best model
# 2m 47s
# Epoch 34/49
# ----------
# learning rate 1e-05
# train: loss: 0.000370
# val: loss: 0.000378
# saving best model
# 2m 46s
# Epoch 35/49
# ----------
# learning rate 1e-05
# train: loss: 0.000369
# val: loss: 0.000377
# saving best model
# 2m 47s
# Epoch 36/49
# ----------
# learning rate 1e-05
# train: loss: 0.000368
# val: loss: 0.000376
# saving best model
# 2m 47s
# Epoch 37/49
# ----------
# learning rate 1e-05
# train: loss: 0.000367
# val: loss: 0.000375
# saving best model
# 2m 47s
# Epoch 38/49
# ----------
# learning rate 1e-05
# train: loss: 0.000366
# val: loss: 0.000375
# 2m 46s
# Epoch 39/49
# ----------
# learning rate 1e-05
# train: loss: 0.000365
# val: loss: 0.000374
# saving best model
# 2m 47s
# Epoch 40/49
# ----------
# learning rate 1e-05
# train: loss: 0.000364
# val: loss: 0.000373
# saving best model
# 2m 46s
# Epoch 41/49
# ----------
# learning rate 1e-05
# train: loss: 0.000363
# val: loss: 0.000374
# 2m 47s
# Epoch 42/49
# ----------
# learning rate 1e-05
# train: loss: 0.000362
# val: loss: 0.000372
# saving best model
# 2m 46s
# Epoch 43/49
# ----------
# learning rate 1e-05
# train: loss: 0.000362
# val: loss: 0.000373
# 2m 47s
# Epoch 44/49
# ----------
# learning rate 1e-05
# train: loss: 0.000361
# val: loss: 0.000370
# saving best model
# 2m 46s
# Epoch 45/49
# ----------
# learning rate 1e-05
# train: loss: 0.000360
# val: loss: 0.000370
# saving best model
# 2m 47s
# Epoch 46/49
# ----------
# learning rate 1e-05
# train: loss: 0.000359
# val: loss: 0.000370
# 2m 46s
# Epoch 47/49
# ----------
# learning rate 1e-05
# train: loss: 0.000359
# val: loss: 0.000369
# saving best model
# 2m 47s
# Epoch 48/49
# ----------
# learning rate 1e-05
# train: loss: 0.000358
# val: loss: 0.000367
# saving best model
# 2m 46s
# Epoch 49/49
# ----------
# learning rate 1e-05
# train: loss: 0.000357
# val: loss: 0.000367
# 2m 47s
# Best val loss: 24.062719

# %% [markdown]
# ## Save Second U Model For Inference

# %%
torch.save(model.state_dict(), 'RadioWNet_s_DPMcars_carInput_Thr2/300samples_SecondU.pt')

# %% [markdown]
# ## Load Second U Model For Inference

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = modules.RadioWNet(inputs=2, phase="secondU")
model.load_state_dict(torch.load('RadioWNet_s_DPMcars_carInput_Thr2/300samples_SecondU.pt'))
model.to(device)
# Out:
# RadioWNet(
#   (layer00): Sequential(
#     (0): Conv2d(2, 6, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer0): Sequential(
#     (0): Conv2d(6, 40, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer1): Sequential(
#     (0): Conv2d(40, 50, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer10): Sequential(
#     (0): Conv2d(50, 60, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(60, 100, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer20): Sequential(
#     (0): Conv2d(100, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer3): Sequential(
#     (0): Conv2d(100, 150, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer4): Sequential(
#     (0): Conv2d(150, 300, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer5): Sequential(
#     (0): Conv2d(300, 500, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_up5): Sequential(
#     (0): ConvTranspose2d(500, 300, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (conv_up4): Sequential(
#     (0): ConvTranspose2d(600, 150, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (conv_up3): Sequential(
#     (0): ConvTranspose2d(300, 100, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (conv_up20): Sequential(
#     (0): Conv2d(200, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_up2): Sequential(
#     (0): ConvTranspose2d(200, 60, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#     (1): ReLU(inplace=True)
#   )
#   (conv_up10): Sequential(
#     (0): Conv2d(120, 50, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_up1): Sequential(
#     (0): ConvTranspose2d(100, 40, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#     (1): ReLU(inplace=True)
#   )
#   (conv_up0): Sequential(
#     (0): ConvTranspose2d(80, 20, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#     (1): ReLU(inplace=True)
#   )
#   (conv_up00): Sequential(
#     (0): Conv2d(28, 20, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_up000): Sequential(
#     (0): Conv2d(22, 1, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer00): Sequential(
#     (0): Conv2d(3, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer0): Sequential(
#     (0): Conv2d(20, 30, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer1): Sequential(
#     (0): Conv2d(30, 40, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer10): Sequential(
#     (0): Conv2d(40, 50, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer2): Sequential(
#     (0): Conv2d(50, 60, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer20): Sequential(
#     (0): Conv2d(60, 70, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer3): Sequential(
#     (0): Conv2d(70, 90, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer4): Sequential(
#     (0): Conv2d(90, 110, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wlayer5): Sequential(
#     (0): Conv2d(110, 150, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wconv_up5): Sequential(
#     (0): ConvTranspose2d(150, 110, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (Wconv_up4): Sequential(
#     (0): ConvTranspose2d(220, 90, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (Wconv_up3): Sequential(
#     (0): ConvTranspose2d(180, 70, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (Wconv_up20): Sequential(
#     (0): Conv2d(140, 60, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wconv_up2): Sequential(
#     (0): ConvTranspose2d(120, 50, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#     (1): ReLU(inplace=True)
#   )
#   (Wconv_up10): Sequential(
#     (0): Conv2d(100, 40, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wconv_up1): Sequential(
#     (0): ConvTranspose2d(80, 30, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#     (1): ReLU(inplace=True)
#   )
#   (Wconv_up0): Sequential(
#     (0): ConvTranspose2d(60, 20, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#     (1): ReLU(inplace=True)
#   )
#   (Wconv_up00): Sequential(
#     (0): Conv2d(43, 20, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Wconv_up000): Sequential(
#     (0): Conv2d(23, 1, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
# )

# %% [markdown]
# ## Test Accuracy

# %%
import torch
import torch.optim as optim
from torch.optim import lr_scheduler
import time
import copy
from collections import defaultdict
import torch.nn.functional as F
import torch.nn as nn

def calc_loss_test(pred1, pred2, target, metrics, error="MSE"):
    criterion = nn.MSELoss()
    if error=="MSE":
        loss1 = criterion(pred1, target)
        loss2 = criterion(pred2, target)
    else:
        loss1 = criterion(pred1, target)/criterion(target, 0*target)
        loss2 = criterion(pred2, target)/criterion(target, 0*target)
    metrics['loss first U'] += loss1.data.cpu().numpy() * target.size(0)
    metrics['loss second U'] += loss2.data.cpu().numpy() * target.size(0)

    return [loss1,loss2]

def print_metrics_test(metrics, epoch_samples, error):
    outputs = []
    if error=="MSE":
        for k in metrics.keys():
            outputs.append("{}: {:4f}".format(k, metrics[k] / (epoch_samples*256**2)))
    else:
        for k in metrics.keys():
            outputs.append("{}: {:4f}".format(k, metrics[k] / epoch_samples))
    print("{}: {}".format("Test"+" "+error, ", ".join(outputs)))

def test_loss(model, error="MSE", dataset="coarse"):
    # dataset is "coarse" or "fine".
    since = time.time()
    model.eval()   # Set model to evaluate mode
    metrics = defaultdict(float)
    epoch_samples = 0
    if dataset=="coarse":
        for inputs, targets in DataLoader(Radio_test, batch_size=batch_size, shuffle=True, num_workers=1):
            inputs = inputs.to(device)
            targets = targets.to(device)
            # do not track history if only in train
            with torch.set_grad_enabled(False):
                [outputs1,outputs2] = model(inputs)
                [loss1,loss2] = calc_loss_test(outputs1, outputs2, targets, metrics, error)
                epoch_samples += inputs.size(0)
    elif dataset=="fine":  
        for inputs, targets, samples in DataLoader(Radio_test, batch_size=batch_size, shuffle=True, num_workers=1):
            inputs = inputs.to(device)
            targets = targets.to(device)
            # do not track history if only in train
            with torch.set_grad_enabled(False):
                [outputs1,outputs2] = model(inputs)
                [loss1,loss2] = calc_loss_test(outputs1, outputs2, targets, metrics, error)
                epoch_samples += inputs.size(0)
    print_metrics_test(metrics, epoch_samples, error)
    #test_loss1 = metrics['loss U'] / epoch_samples
    #test_loss2 = metrics['loss W'] / epoch_samples
    time_elapsed = time.time() - since
    print('{:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))

# %% [markdown]
# ### MSE Accuracy on DPM

# %%
test_loss(model,error="MSE")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 test_loss(model,error="MSE")
#
# Cell In[16], line 40, in test_loss(model, error, dataset)
#      38 epoch_samples = 0
#      39 if dataset=="coarse":
# ---> 40     for inputs, targets in DataLoader(Radio_test, batch_size=batch_size, shuffle=True, num_workers=1):
#      41         inputs = inputs.to(device)
#      42         targets = targets.to(device)
#
# File ~/anaconda3/envs/llm/lib/python3.11/site-packages/torch/utils/data/dataloader.py:484, in DataLoader.__iter__(self)
#     482     return self._iterator
#     483 else:
# --> 484     return self._get_iterator()
#
# File ~/anaconda3/envs/llm/lib/python3.11/site-packages/torch/utils/data/dataloader.py:415, in DataLoader._get_iterator(self)
#     413 else:
#     414     self.check_worker_number_rationality()
# --> 415     return _MultiProcessingDataLoaderIter(self)
#
# File ~/anaconda3/envs/llm/lib/python3.11/site-packages/torch/utils/data/dataloader.py:1191, in _MultiProcessingDataLoaderIter.__init__(self, loader)
#    1189 _utils.signal_handling._set_SIGCHLD_handler()
#    1190 self._worker_pids_set = True
# -> 1191 self._reset(loader, first_iter=True)
#
# File ~/anaconda3/envs/llm/lib/python3.11/site-packages/torch/utils/data/dataloader.py:1228, in _MultiProcessingDataLoaderIter._reset(self, loader, first_iter)
#    1226 # prime the prefetch loop
#    1227 for _ in range(self._prefetch_factor * self._num_workers):
# -> 1228     self._try_put_index()
#
# File ~/anaconda3/envs/llm/lib/python3.11/site-packages/torch/utils/data/dataloader.py:1471, in _MultiProcessingDataLoaderIter._try_put_index(self)
#    1468 assert self._tasks_outstanding < self._prefetch_factor * self._num_workers
#    1470 try:
# -> 1471     index = self._next_index()
#    1472 except StopIteration:
#    1473     return
#
# File ~/anaconda3/envs/llm/lib/python3.11/site-packages/torch/utils/data/dataloader.py:691, in _BaseDataLoaderIter._next_index(self)
#     690 def _next_index(self):
# --> 691     return next(self._sampler_iter)
#
# File ~/anaconda3/envs/llm/lib/python3.11/site-packages/torch/utils/data/sampler.py:347, in BatchSampler.__iter__(self)
#     345 batch = [0] * self.batch_size
#     346 idx_in_batch = 0
# --> 347 for idx in self.sampler:
#     348     batch[idx_in_batch] = idx
#     349     idx_in_batch += 1
#
# File ~/anaconda3/envs/llm/lib/python3.11/site-packages/torch/utils/data/sampler.py:197, in RandomSampler.__iter__(self)
#     195 else:
#     196     for _ in range(self.num_samples // n):
# --> 197         yield from torch.randperm(n, generator=generator).tolist()
#     198     yield from torch.randperm(n, generator=generator).tolist()[
#     199         : self.num_samples % n
#     200     ]
#
# RuntimeError: Expected a 'cuda' device type for generator but found 'cpu'

# %% [markdown]
# ### NMSE Accuracy on DPM

# %%
test_loss(model,error="NMSE")

# %% [markdown]
# ## Sampled IRT4 Data Loader

# %%
Radio_train = loaders.RadioUNet_s_sprseIRT4(phase="train", carsSimul="yes", carsInput="yes", data_samples=600)
Radio_val = loaders.RadioUNet_s_sprseIRT4(phase="val", carsSimul="yes", carsInput="yes", data_samples=600)
Radio_test = loaders.RadioUNet_s_sprseIRT4(phase="test", carsSimul="yes", carsInput="yes", data_samples=600)

image_datasets = {
    'train': Radio_train, 'val': Radio_val
}

batch_size = 15

dataloaders = {
    'train': DataLoader(Radio_train, batch_size=batch_size, shuffle=True, num_workers=1),
    'val': DataLoader(Radio_val, batch_size=batch_size, shuffle=True, num_workers=1)
}

# %% [markdown]
# ## Test Zer-Shot Accuracy On IRT4

# %% [markdown]
# ### MSE Accuracy on IRT4

# %%
test_loss(model,error="MSE", dataset="fine")

# %% [markdown]
# ### NMSE Accuracy on IRT4

# %%
test_loss(model,error="NMSE", dataset="fine")

# %% [markdown]
# ## Training Sampled IRT4 UNet

# %%
import torch
import torch.optim as optim
from torch.optim import lr_scheduler
import time
import copy

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)


optimizer_ft = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-4)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=30, gamma=0.1)

model = train_model(model, optimizer_ft, exp_lr_scheduler, WNetPhase="secondU", targetType="sparse", num_samples=600)

# %% [markdown]
# ## Save Adaptation to IRT4 Model For Inference

# %%
torch.save(model.state_dict(), 'RadioWNet_s_DPMcars_carInput_Thr2/Trained_Model_IRT4.pt')

# %% [markdown]
# ## Load Adaptation to IRT4 Model For Inference

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = modules.RadioWNet(inputs=4, phase="secondU")
model.load_state_dict(torch.load('RadioWNet_s_DPMcars_carInput_Thr2/Trained_Model_IRT4.pt'))
model.to(device)

# %% [markdown]
# ## Test Adaptation to IRT4 Accuracy On IRT4

# %% [markdown]
# ### MSE Accuracy on IRT4

# %%
test_loss(model,error="MSE", dataset="fine")

# %% [markdown]
# ### NMSE Accuracy on IRT4

# %%
test_loss(model,error="NMSE", dataset="fine")

# %% [markdown]
# # Save Image Examples

# %% [markdown]
# ## Create Directory For Saving Examples

# %%
import os
try: 
    os.mkdir('RadioWNet_s_DPMcars_carInput_Thr2/Examples') 
except OSError as error: 
    print(error)

# %% [markdown]
# ## Save Examples IRT4

# %%
maps_inds=np.arange(0,700,1,dtype=np.int16)
#Standard determenistic "random" shuffle of the maps:
np.random.seed(42)
np.random.shuffle(maps_inds)
            
from PIL import Image
for mapp in range(1,99):
    name00=str(mapp)
    name0=str(maps_inds[600+mapp])
    Radio_test2 = loaders.RadioUNet_s_sprseIRT4(maps_inds=maps_inds, phase="custom", 
                                               ind1=600+mapp, ind2=600+mapp, 
                                               carsSimul="yes", carsInput="yes", data_samples=600)
    
   
    ii=0
    for inputs, target, samps in DataLoader(Radio_test2, batch_size=1, shuffle=False, num_workers=0):
        ii=ii+1
        inputs = inputs.to(device)
        target = target.to(device)
        pred1, pred = model(inputs)
        pred = (pred.detach().cpu().numpy()).astype(np.uint8)
        builds=inputs.detach().cpu().numpy()
        cars=builds[0][3]
        builds=builds[0][0]
        indB=builds!=0
        indC=cars!=0
        inputs = (inputs.detach().cpu().numpy()).astype(np.uint8)
        im=np.zeros([256,256,3])
        #imT=np.zeros([256,256,3])
        im[:,:,0] = (pred[0][0])
        im[:,:,1] = (pred[0][0])
        im[:,:,2] = (pred[0][0])
        im[indB,2]=180
        im[indC,1]=180
        #imT=im
        ind0=inputs[0][2]!=0
        ind1=inputs[0][2]>=100 
        im[ind0,1]=0
        im[ind0,0]=255
        im[ind0,2]=20
        im[ind1,0]=80
        im[ind1,2]=0
        im = Image.fromarray(im.astype(np.uint8))

        name=str(ii)
        #file_name="buildC_carsN_simulD_DMP_samplesN/%spredict.png" %name
        file_name="RadioWNet_s_DPMcars_carInput_Thr2/Examples/" +name00+ "_"+name0+ "_"+ name + "IRT4_predict.png" 
        im.save(file_name)
        #file_name="%spredict.png" %name
        im = Image.fromarray(255*inputs[0][2])
        file_name="RadioWNet_s_DPMcars_carInput_Thr2/Examples/" +name00+ "_"+name0+ "_"+ name + "IRT4_samples.png" 
        im.save(file_name)
        Gtruth = (target.detach().cpu().numpy() )#.astype(np.uint8)
        im=np.zeros([256,256,3])
        im[:,:,0]=Gtruth[0][0]
        im[:,:,1]=Gtruth[0][0]
        im[:,:,2]=Gtruth[0][0]
        im[indB,2]=180
        im[indC,1]=180
        im = Image.fromarray(im.astype(np.uint8))
        #file_name="buildC_carsN_simulD_DMP_samplesN/%starget.png" %name
        file_name="RadioWNet_s_DPMcars_carInput_Thr2/Examples/" +name00+ "_"+name0+ "_"+ name + "IRT4_target.png"
        #file_name="%starget.png" %name
        im.save(file_name)

# %% [markdown]
# ## Save Image Examples for DPM Data

# %% [markdown]
# ### Load DPM Model For Inference

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = modules.RadioWNet(inputs=4, phase="secondU")
model.load_state_dict(torch.load('RadioWNet_s_DPMcars_carInput_Thr2/Trained_Model_SecondU.pt'))
model.to(device)

# %% [markdown]
# ## Save Examples DPM

# %%
maps_inds=np.arange(0,700,1,dtype=np.int16)
#Standard determenistic "random" shuffle of the maps:
np.random.seed(42)
np.random.shuffle(maps_inds)
            
from PIL import Image
for mapp in range(1,99):
    name00=str(mapp)
    name0=str(maps_inds[600+mapp])
    Radio_test2 = loaders.RadioUNet_s(maps_inds=maps_inds, phase="custom", 
                                               ind1=600+mapp, ind2=600+mapp, 
                                               carsSimul="yes", carsInput="yes")
    
   
    ii=0
    for inputs, target in DataLoader(Radio_test2, batch_size=1, shuffle=False, num_workers=0):
        ii=ii+1
        if ii>2:
            break
        inputs = inputs.to(device)
        target = target.to(device)
        pred1, pred = model(inputs)
        pred = (pred.detach().cpu().numpy()).astype(np.uint8)
        builds=inputs.detach().cpu().numpy()
        cars=builds[0][3]
        builds=builds[0][0]
        indB=builds!=0
        indC=cars!=0
        inputs = (inputs.detach().cpu().numpy()).astype(np.uint8)
        im=np.zeros([256,256,3])
        #imT=np.zeros([256,256,3])
        im[:,:,0] = (pred[0][0])
        im[:,:,1] = (pred[0][0])
        im[:,:,2] = (pred[0][0])
        im[indB,2]=180
        im[indC,1]=180
        #imT=im
        ind0=inputs[0][2]!=0
        ind1=inputs[0][2]>=100 
        im[ind0,1]=0
        im[ind0,0]=255
        im[ind0,2]=20
        im[ind1,0]=80
        im[ind1,2]=0
        im = Image.fromarray(im.astype(np.uint8))

        name=str(ii)
        #file_name="buildC_carsN_simulD_DMP_samplesN/%spredict.png" %name
        file_name="RadioWNet_s_DPMcars_carInput_Thr2/Examples/" +name00+ "_"+name0+ "_"+ name + "DPM_predict.png" 
        im.save(file_name)
        #file_name="%spredict.png" %name
        im = Image.fromarray(255*inputs[0][2])
        file_name="RadioWNet_s_DPMcars_carInput_Thr2/Examples/" +name00+ "_"+name0+ "_"+ name + "DPM_samples.png" 
        im.save(file_name)
        Gtruth = (target.detach().cpu().numpy() )#.astype(np.uint8)
        im=np.zeros([256,256,3])
        im[:,:,0]=Gtruth[0][0]
        im[:,:,1]=Gtruth[0][0]
        im[:,:,2]=Gtruth[0][0]
        im[indB,2]=180
        im[indC,1]=180
        im = Image.fromarray(im.astype(np.uint8))
        #file_name="buildC_carsN_simulD_DMP_samplesN/%starget.png" %name
        file_name="RadioWNet_s_DPMcars_carInput_Thr2/Examples/" +name00+ "_"+name0+ "_"+ name + "DPM_target.png"
        #file_name="%starget.png" %name
        im.save(file_name)

# %% [markdown]
# ## Show examples

# %%
fig, axarr = plt.subplots(2,2, figsize=(8, 8))


im=io.imread("RadioWNet_s_DPMcars_carInput_Thr2/Examples/17_187_1DPM_target.png")
fig.add_subplot(2, 2, 1)
plt.imshow(im)
axarr[0, 0].set_title('Target DPM')

im=io.imread("RadioWNet_s_DPMcars_carInput_Thr2/Examples/17_187_1DPM_predict.png")
fig.add_subplot(2, 2, 2)
plt.imshow(im)
axarr[0, 1].set_title('Predicted DPM')

im=io.imread("RadioWNet_s_DPMcars_carInput_Thr2/Examples/17_187_1IRT4_target.png")
fig.add_subplot(2, 2, 3)
plt.imshow(im)
axarr[1, 0].set_title('Target IRT2')

im=io.imread("RadioWNet_s_DPMcars_carInput_Thr2/Examples/17_187_1IRT4_predict.png")
fig.add_subplot(2, 2, 4)
plt.imshow(im)
axarr[1, 1].set_title('Predicted IRT2')

# %%
fig, axarr = plt.subplots(2,2, figsize=(8, 8))


im=io.imread("RadioWNet_s_DPMcars_carInput_Thr2/Examples/41_508_2DPM_target.png")
fig.add_subplot(2, 2, 1)
plt.imshow(im)
axarr[0, 0].set_title('Target DPM')

im=io.imread("RadioWNet_s_DPMcars_carInput_Thr2/Examples/41_508_2DPM_predict.png")
fig.add_subplot(2, 2, 2)
plt.imshow(im)
axarr[0, 1].set_title('Predicted DPM')

im=io.imread("RadioWNet_s_DPMcars_carInput_Thr2/Examples/41_508_2IRT4_target.png")
fig.add_subplot(2, 2, 3)
plt.imshow(im)
axarr[1, 0].set_title('Target IRT2')

im=io.imread("RadioWNet_s_DPMcars_carInput_Thr2/Examples/41_508_2IRT4_predict.png")
fig.add_subplot(2, 2, 4)
plt.imshow(im)
axarr[1, 1].set_title('Predicted IRT2')

# %%
fig, axarr = plt.subplots(2,2, figsize=(8, 8))


im=io.imread("RadioWNet_s_DPMcars_carInput_Thr2/Examples/31_476_2DPM_target.png")
fig.add_subplot(2, 2, 1)
plt.imshow(im)
axarr[0, 0].set_title('Target DPM')

im=io.imread("RadioWNet_s_DPMcars_carInput_Thr2/Examples/31_476_2DPM_predict.png")
fig.add_subplot(2, 2, 2)
plt.imshow(im)
axarr[0, 1].set_title('Predicted DPM')

im=io.imread("RadioWNet_s_DPMcars_carInput_Thr2/Examples/31_476_2IRT4_target.png")
fig.add_subplot(2, 2, 3)
plt.imshow(im)
axarr[1, 0].set_title('Target IRT2')

im=io.imread("RadioWNet_s_DPMcars_carInput_Thr2/Examples/31_476_2IRT4_predict.png")
fig.add_subplot(2, 2, 4)
plt.imshow(im)
axarr[1, 1].set_title('Predicted IRT2')
